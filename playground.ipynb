# %% [markdown]
# <a href="https://colab.research.google.com/github/Sofy34/12.08/blob/master/playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import pandas as pd
import subprocess
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import re
import glob
global sent_tex_db
global sent_tokens_db
import psutil

# %%
db_path = "/content/drive/MyDrive/MSc_2020/Thesis/Tmp/DataBases"
step_print = 100
db_step=300

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# !whoami
# Out:
# root

# %%
# !lsof | grep /content/yapproj/src/yap/yap  | awk '{print $2}' | xargs kill

# %%
localhost_yap = "http://localhost:8000/yap/heb/joint"

# %%
def read_data():
  return pd.read_csv(os.path.join(db_path,"sent_db.csv"),usecols=['text'])

# %%
# reader = pd.read_csv(os.path.join(db_path,"sent_db.csv"),usecols=['text'],chunksize=db_step,iterator=True)
# reader

# %%
# for chunk in reader:
#  display(chunk.head())

# %%
# sent_text_db = read_data()

# %%
# sent_text_db['text'].str.contains("\t").any()

# %%
def install_go():
  # !apt update
  # !apt upgrade
  # !apt search golang-go
  # !apt search gccgo-go
  # !apt install golang-go

# %%
def set_up_yap_git():
  # !mkdir yapproj
  # %cd yapproj
  # %env GOPATH=/content/yapproj
  # !mkdir src
  # %cd src
  # !git clone https://github.com/OnlpLab/yap.git

# %%
def build_yap():
  # %cd /content/yapproj/src/yap
  # !bunzip2 data/*.bz2

# %%
def go_get_build():
  # %cd /content/yapproj/src/yap
  # !go get .
  # !go build .

# %%
set_up_yap_git()
install_go()
build_yap()
go_get_build()
# Out:
# /content/yapproj
# env: GOPATH=/content/yapproj
# /content/yapproj/src
# Cloning into 'yap'...
# remote: Enumerating objects: 7066, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 7066 (delta 18), reused 38 (delta 15), pack-reused 7023
# Receiving objects: 100% (7066/7066), 125.45 MiB | 26.65 MiB/s, done.
# Resolving deltas: 100% (4241/4241), done.
# Get:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:2 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:4 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:6 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# ...

# %%
def start_yap_api():
  # %cd /content/yapproj/src/yap
  cmd = "! ./yap api "
  process = subprocess.Popen(cmd,stdout=subprocess.PIPE,cwd="/content/yapproj/src/yap/",shell=True)
  return process

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 27.3 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
def kill_yap_api(proc_pid):
    process = psutil.Process(proc_pid)
    for proc in process.children(recursive=True):
        proc.kill()
    process.kill()

# %%
server_p  = start_yap_api()
server_p.poll()
# Out:
# /content/yapproj/src/yap

# %%
# kill_yap_api(server_p.pid)

# %% [markdown]
# # New Section

# %%
try_text = 'גנן גידל דגן בגן'
localhost_yap = "http://localhost:8000/yap/heb/joint"
data = '{{"text": "{}  "}}'.format(try_text).encode('utf-8')  # input string ends with two space characters
headers = {'content-type': 'application/json'}
response = requests.get(url=localhost_yap, data=data, headers=headers)
json_response = response.json()
json_response
# Out:
# {'dep_tree': '1\tגנן\tגנן\tNN\tNN\tgen=M|num=S\t2\tsubj\t_\t_\n2\tגידל\tגידל\tVB\tVB\tgen=M|num=S|per=3|tense=PAST\t0\tROOT\t_\t_\n3\tדגן\tדגן\tNN\tNN\tgen=M|num=S\t2\tobj\t_\t_\n4\tב\tב\tPREPOSITION\tPREPOSITION\t\t2\tprepmod\t_\t_\n5\tה\tה\tDEF\tDEF\t\t6\tdef\t_\t_\n6\tגן\tגן\tNN\tNN\tgen=M|num=S\t4\tpobj\t_\t_\n\n',
# ...

# %%
yap_tag_list = ['FROM','TO','FORM','LEMMA','CPOSTAG','POSTAG','FEATS','TOKEN']
# FROM: Index of the outgoing vertex of the edge
# TO: Index of the incoming vertex of the edge
# FORM: word form or punctuation mark
# LEMMA: Lemma of the word form; underscore if not available
# CPOSTAG: Coarse-grained part-of-speech tag; underscore if not available
# POSTAG: Fine-grained part-of-speech tag; underscore if not available; in YAP both POSTAG and CPOSTAG are always identical
# FEATS: List of morphological features separated by a vertical bar (|) from a pre-defined language-specific inventory; underscore if not available
# TOKEN: Source token index


def get_server_response(text,sent_idx):
  data = '{{"text": "{}  "}}'.format(text).encode('utf-8')  # input string ends with two space characters
  headers = {'content-type': 'application/json'}
  response = requests.get(url=localhost_yap, data=data, headers=headers)
  json_response = response.json()
  md_string = json_response.get('md_lattice','')
  if len(md_string) == 0:
    print("ERROR in get_server_response for {}\n{}".format(sent_idx,sent_text_db.iloc[sent_idx]))
  return md_string

def clean_server_response(text,sent_idx):
  clean_text= re.sub(r"(^./|.$/)","",text)
  clean_text = re.sub("\\t","\t",clean_text)
  clean_text = re.sub("\\n","\n",clean_text)
  return clean_text

def parse_server_response(text,sent_idx):
  rows = text.split("\n")
  for i,r in enumerate(rows):
    curr_word_idx = sent_tokens_db.shape[0]
    row_split = r.split('\t')
    for j,token in enumerate(row_split):
      if(len(token) == 0):
        continue
      sent_tokens_db.loc[curr_word_idx,yap_tag_list[j]] = token
      sent_tokens_db.loc[curr_word_idx,'sent_idx'] = sent_idx
      if(yap_tag_list[j] == 'FEATS' and '|' in token):
          feats_list = token.split("|")
          for n,fea in enumerate(feats_list):
            [name,value] = fea.split("=")
            sent_tokens_db.loc[curr_word_idx,"f_{}".format(name)] = value

def sent_to_tags(sent_idx):
  global sent_text_db
  text = sent_text_db.loc[sent_idx,'text']
  resp = get_server_response(text,sent_idx)
  if(sent_idx%step_print == 0):
    print("{} got response".format(sent_idx))
  if(len(resp)!=0):
    resp = clean_server_response(resp,sent_idx)
    if(sent_idx%step_print == 0):
      print("\t{} response cleaned".format(sent_idx))
    parse_server_response(resp,sent_idx)
    if(sent_idx%step_print == 0):
      print("\t{} response parsed".format(sent_idx))



def parse_all_sentenses(doc_list):
  global sent_text_db
  global sent_tokens_db
  doc_num = len(doc_list)
  for doc_idx,doc_path in enumerate(doc_list):
      print("Started doc {} of {}".format(doc_idx,doc_num))
      sent_text_db = pd.read_csv(doc_path,usecols=['text','doc_idx'])
      sent_tokens_db = pd.DataFrame()
      doc_idx_from_name = int(sent_text_db.loc[0,'doc_idx'])
      local_name = "{:02d}_sent_pos_db.csv".format(doc_idx_from_name)
      for sent_idx in sent_text_db.index:
        sent_to_tags(sent_idx)
      sent_tokens_db = sent_tokens_db.assign(doc_idx = sent_text_db['doc_idx'])
      sent_tokens_db.to_csv(os.path.join(db_path,local_name),index=False)
      del sent_tokens_db
      del sent_text_db
      # sent_tokens_db.to_csv(local_name,index=False)
      print('Saved db {}'.format(local_name))

# %%
doc_list = glob.glob(os.path.join(db_path, "*_sent_db.csv"))
doc_list.sort()
doc_list
# Out:
# ['/content/drive/MyDrive/MSc_2020/Thesis/Tmp/DataBases/01_sent_db.csv',
#  '/content/drive/MyDrive/MSc_2020/Thesis/Tmp/DataBases/02_sent_db.csv',
#  '/content/drive/MyDrive/MSc_2020/Thesis/Tmp/DataBases/03_sent_db.csv',
#  '/content/drive/MyDrive/MSc_2020/Thesis/Tmp/DataBases/04_sent_db.csv',
#  '/content/drive/MyDrive/MSc_2020/Thesis/Tmp/DataBases/05_sent_db.csv',
#  '/content/drive/MyDrive/MSc_2020/Thesis/Tmp/DataBases/06_sent_db.csv',
#  '/content/drive/MyDrive/MSc_2020/Thesis/Tmp/DataBases/07_sent_db.csv',
#  '/content/drive/MyDrive/MSc_2020/Thesis/Tmp/DataBases/08_sent_db.csv',
#  '/content/drive/MyDrive/MSc_2020/Thesis/Tmp/DataBases/09_sent_db.csv',
#  '/content/drive/MyDrive/MSc_2020/Thesis/Tmp/DataBases/10_sent_db.csv',
#  '/content/drive/MyDrive/MSc_2020/Thesis/Tmp/DataBases/11_sent_db.csv',
#  '/content/drive/MyDrive/MSc_2020/Thesis/Tmp/DataBases/12_sent_db.csv',
#  '/content/drive/MyDrive/MSc_2020/Thesis/Tmp/DataBases/13_sent_db.csv',
# ...

# %%
# selected_doc = [doc_list[8],doc_list[62]]
selected_doc = doc_list

# %%
# doc_sub_list = [doc_list[i-1] for i in selected_doc]
# doc_sub_list

# %%
parse_all_sentenses(doc_list)
# Out:
# Started doc 0 of 80
# 0 got response
# 	0 response cleaned
# 	0 response parsed
# 100 got response
# 	100 response cleaned
# 	100 response parsed
# 200 got response
# 	200 response cleaned
# 	200 response parsed
# 300 got response
# 	300 response cleaned
# 	300 response parsed
# 400 got response
# 	400 response cleaned
# 	400 response parsed
# 500 got response
# 	500 response cleaned
# 	500 response parsed
# Saved db 01_sent_pos_db.csv
# Started doc 1 of 80
# 0 got response
# 	0 response cleaned
# 	0 response parsed
# 100 got response
# 	100 response cleaned
# 	100 response parsed
# 200 got response
# 	200 response cleaned
# 	200 response parsed
# 300 got response
# 	300 response cleaned
# 	300 response parsed
# 400 got response
# 	400 response cleaned
# 	400 response parsed
# 500 got response
# 	500 response cleaned
# 	500 response parsed
# 600 got response
# 	600 response cleaned
# 	600 response parsed
# Saved db 02_sent_pos_db.csv
# Started doc 2 of 80
# 0 got response
# ...

# %%
   doc_list = glob.glob(os.path.join(db_path, "*_sent_pos_db.csv"))
  doc_list.sort()
# Out:
#   File "<ipython-input-1-f78661ecafd0>", line 2
#     doc_list.sort()
#     ^
# IndentationError: unexpected indent

# %%
doc_list[8]
# Out:
# '/content/drive/MyDrive/MSc_2020/Thesis/Tmp/DataBases/10_sent_pos_db.csv'

# %%
  doc_list = glob.glob(os.path.join(db_path, "*_sent_db.csv"))
  doc_num = len(doc_list)
  for doc_idx,doc_path in enumerate(doc_list):
      doc_idx_from_name = int(os.path.basename(doc_path).split('_')[0])
      print(doc_idx_from_name)
# Out:
# 2
# 0
# 5
# 1
# 4
# 7
# 6
# 3
